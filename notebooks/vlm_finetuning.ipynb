# %% [markdown]
# # Fine-Tuning a Generative VLM for Image Describing

# %% [markdown]
# ## Installing dependencies

# %%
# !pip install -q peft transformers bitsandbytes datasets fsspec==2025.3.0 evaluate pycocoevalcap

# %%
import os
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import torch
from transformers import AutoProcessor, Blip2ForConditionalGeneration
from peft import LoraConfig, get_peft_model
import matplotlib.pyplot as plt
from collections import defaultdict
import evaluate
from pycocoevalcap.cider.cider import Cider
from pycocoevalcap.tokenizer.ptbtokenizer import PTBTokenizer
# Out:
# 2025-05-01 16:41:08.687901: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746117668.862338      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746117668.915176      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
df = pd.read_csv("/kaggle/input/flickr8k/captions.txt")
df = df.dropna().reset_index(drop=True)
df.to_csv("flickr8k_captions.csv", index=False)

# %%
class Flickr8kDataset(Dataset):
    def __init__(self, captions_file, image_dir, processor,max_samples=8000):
      self.image_dir = image_dir
      self.processor = processor
      df = pd.read_csv(captions_file)
      df = df.sample(n=max_samples, random_state=42).reset_index(drop=True)
      self.samples = df
    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        row = self.samples.iloc[idx]
        image_path = os.path.join(self.image_dir, row["image"])
        caption = row["caption"]

        # Load image
        image = Image.open(image_path).convert('RGB')

        # Process image
        inputs = self.processor(images=image, return_tensors="pt")
        inputs = {k: v.squeeze() for k, v in inputs.items()}
        inputs["text"] = caption

        return inputs

def collate_fn(batch):
    processed_batch = {}
    for key in batch[0].keys():
        if key != "text":
            processed_batch[key] = torch.stack([example[key] for example in batch])
        else:
            text_inputs = processor.tokenizer(
                [example["text"] for example in batch], padding=True, return_tensors="pt"
            )
            processed_batch["input_ids"] = text_inputs["input_ids"]
            processed_batch["attention_mask"] = text_inputs["attention_mask"]
    return processed_batch

# %%
processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained(
    "ybelkada/blip2-opt-2.7b-fp16-sharded",
    device_map="auto",
    load_in_8bit=True
)
# Apply LoRA
config = LoraConfig(
    r=8,
    lora_alpha=16,
    lora_dropout=0.01,
    bias="none",
    target_modules=["q_proj", "k_proj"]
)
model = get_peft_model(model, config)
model.print_trainable_parameters()
# Out:
# processor_config.json:   0%|          | 0.00/68.0 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/882 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.56M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/7.05k [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# pytorch_model.bin.index.json:   0%|          | 0.00/122k [00:00<?, ?B/s]
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# pytorch_model-00006-of-00008.bin:   0%|          | 0.00/997M [00:00<?, ?B/s]
# pytorch_model-00007-of-00008.bin:   0%|          | 0.00/997M [00:00<?, ?B/s]
# pytorch_model-00005-of-00008.bin:   0%|          | 0.00/997M [00:00<?, ?B/s]
# pytorch_model-00002-of-00008.bin:   0%|          | 0.00/999M [00:00<?, ?B/s]
# pytorch_model-00008-of-00008.bin:   0%|          | 0.00/782M [00:00<?, ?B/s]
# pytorch_model-00001-of-00008.bin:   0%|          | 0.00/995M [00:00<?, ?B/s]
# pytorch_model-00004-of-00008.bin:   0%|          | 0.00/997M [00:00<?, ?B/s]
# pytorch_model-00003-of-00008.bin:   0%|          | 0.00/985M [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/127k [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# trainable params: 2,621,440 || all params: 3,747,301,376 || trainable%: 0.0700

# %%
def execute_training_cycle(model, dataloader, optimizer, device, epochs=2):
    model.train()

    for current_epoch in range(epochs):
        epoch_loss = 0.0
        processed_batches = 0

        print(f"\nCommencing training epoch {current_epoch + 1}/{epochs}")

        for batch_idx, data_batch in enumerate(dataloader):
            # Prepare batch data with explicit device placement
            model_inputs = {
                'input_ids': data_batch['input_ids'].to(device),
                'pixel_values': data_batch['pixel_values'].to(device, torch.float16),
                'labels': data_batch['input_ids'].to(device)  # Using input_ids as labels for LM
            }

            # Forward propagation with gradient computation
            model_output = model(**model_inputs)
            batch_loss = model_output.loss

            # Backward pass and optimization
            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()

            # Progress tracking
            epoch_loss += batch_loss.item()
            processed_batches += 1

            if batch_idx % 10 == 0:
                avg_loss = epoch_loss / (batch_idx + 1)
                print(f"Epoch {current_epoch + 1} | Batch {batch_idx} | Avg Loss: {avg_loss:.4f} | Current Loss: {batch_loss.item():.4f}")

        # Epoch summary
        epoch_mean_loss = epoch_loss / len(dataloader)
        print(f"\nEpoch {current_epoch + 1} completed")
        print(f"Average epoch loss: {epoch_mean_loss:.4f}")
        print("-" * 50)

# %%
# Load dataset
train_dataset = Flickr8kDataset("flickr8k_captions.csv","/kaggle/input/flickr8k/Images", processor)
train_dataloader = DataLoader(train_dataset, shuffle=True, batch_size=16, collate_fn=collate_fn)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
device = "cuda" if torch.cuda.is_available() else "cpu"
execute_training_cycle(model, train_dataloader, optimizer, device)
# Out:
# Commencing training epoch 1/2
# Expanding inputs for image tokens in BLIP-2 should be done in processing. Please follow instruction here (https://gist.github.com/zucchini-nlp/e9f20b054fa322f84ac9311d9ab67042) to update your BLIP-2 model. Using processors without these attributes in the config is deprecated and will throw an error in v4.50.
# Epoch 1 | Batch 0 | Avg Loss: 6.5234 | Current Loss: 6.5234
# Epoch 1 | Batch 10 | Avg Loss: 6.2294 | Current Loss: 6.4492
# Epoch 1 | Batch 20 | Avg Loss: 5.8955 | Current Loss: 5.2617
# Epoch 1 | Batch 30 | Avg Loss: 5.4697 | Current Loss: 3.8652
# Epoch 1 | Batch 40 | Avg Loss: 5.0368 | Current Loss: 3.5371
# Epoch 1 | Batch 50 | Avg Loss: 4.6845 | Current Loss: 3.0352
# Epoch 1 | Batch 60 | Avg Loss: 4.3669 | Current Loss: 2.4395
# Epoch 1 | Batch 70 | Avg Loss: 4.1102 | Current Loss: 2.4570
# Epoch 1 | Batch 80 | Avg Loss: 3.8900 | Current Loss: 2.0469
# Epoch 1 | Batch 90 | Avg Loss: 3.7088 | Current Loss: 2.4531
# Epoch 1 | Batch 100 | Avg Loss: 3.5457 | Current Loss: 2.1426
# Epoch 1 | Batch 110 | Avg Loss: 3.4044 | Current Loss: 1.8135
# Epoch 1 | Batch 120 | Avg Loss: 3.2827 | Current Loss: 1.8418
# Epoch 1 | Batch 130 | Avg Loss: 3.1760 | Current Loss: 1.8711
# Epoch 1 | Batch 140 | Avg Loss: 3.0761 | Current Loss: 1.7119
# Epoch 1 | Batch 150 | Avg Loss: 2.9934 | Current Loss: 1.8857
# Epoch 1 | Batch 160 | Avg Loss: 2.9168 | Current Loss: 1.5225
# Epoch 1 | Batch 170 | Avg Loss: 2.8383 | Current Loss: 1.8154
# Epoch 1 | Batch 180 | Avg Loss: 2.7796 | Current Loss: 1.6963
# Epoch 1 | Batch 190 | Avg Loss: 2.7202 | Current Loss: 1.8682
# Epoch 1 | Batch 200 | Avg Loss: 2.6637 | Current Loss: 1.4355
# Epoch 1 | Batch 210 | Avg Loss: 2.6166 | Current Loss: 1.5459
# Epoch 1 | Batch 220 | Avg Loss: 2.5665 | Current Loss: 1.2910
# Epoch 1 | Batch 230 | Avg Loss: 2.5211 | Current Loss: 1.5908
# Epoch 1 | Batch 240 | Avg Loss: 2.4788 | Current Loss: 1.4209
# Epoch 1 | Batch 250 | Avg Loss: 2.4388 | Current Loss: 1.6309
# Epoch 1 | Batch 260 | Avg Loss: 2.4000 | Current Loss: 1.1816
# Epoch 1 | Batch 270 | Avg Loss: 2.3641 | Current Loss: 1.6094
# Epoch 1 | Batch 280 | Avg Loss: 2.3327 | Current Loss: 1.4824
# Epoch 1 | Batch 290 | Avg Loss: 2.3050 | Current Loss: 1.3193
# Epoch 1 | Batch 300 | Avg Loss: 2.2759 | Current Loss: 1.4619
# Epoch 1 | Batch 310 | Avg Loss: 2.2495 | Current Loss: 1.7705
# Epoch 1 | Batch 320 | Avg Loss: 2.2257 | Current Loss: 1.6621
# Epoch 1 | Batch 330 | Avg Loss: 2.2015 | Current Loss: 1.4131
# Epoch 1 | Batch 340 | Avg Loss: 2.1812 | Current Loss: 1.8535
# Epoch 1 | Batch 350 | Avg Loss: 2.1583 | Current Loss: 1.1797
# Epoch 1 | Batch 360 | Avg Loss: 2.1369 | Current Loss: 1.1289
# Epoch 1 | Batch 370 | Avg Loss: 2.1167 | Current Loss: 1.1582
# Epoch 1 | Batch 380 | Avg Loss: 2.0975 | Current Loss: 1.4219
# Epoch 1 | Batch 390 | Avg Loss: 2.0789 | Current Loss: 0.9810
# Epoch 1 | Batch 400 | Avg Loss: 2.0611 | Current Loss: 1.5127
# Epoch 1 | Batch 410 | Avg Loss: 2.0425 | Current Loss: 1.2979
# Epoch 1 | Batch 420 | Avg Loss: 2.0261 | Current Loss: 1.1211
# Epoch 1 | Batch 430 | Avg Loss: 2.0101 | Current Loss: 1.7168
# Epoch 1 | Batch 440 | Avg Loss: 1.9962 | Current Loss: 1.5957
# Epoch 1 | Batch 450 | Avg Loss: 1.9835 | Current Loss: 1.3760
# Epoch 1 | Batch 460 | Avg Loss: 1.9708 | Current Loss: 1.5947
# Epoch 1 | Batch 470 | Avg Loss: 1.9562 | Current Loss: 1.0752
# Epoch 1 | Batch 480 | Avg Loss: 1.9438 | Current Loss: 1.3057
# Epoch 1 | Batch 490 | Avg Loss: 1.9313 | Current Loss: 1.1543
#
# Epoch 1 completed
# Average epoch loss: 1.9212
# --------------------------------------------------
#
# Commencing training epoch 2/2
# Epoch 2 | Batch 0 | Avg Loss: 1.1846 | Current Loss: 1.1846
# Epoch 2 | Batch 10 | Avg Loss: 1.3060 | Current Loss: 1.3867
# Epoch 2 | Batch 20 | Avg Loss: 1.3410 | Current Loss: 1.6162
# Epoch 2 | Batch 30 | Avg Loss: 1.3133 | Current Loss: 1.2070
# Epoch 2 | Batch 40 | Avg Loss: 1.3281 | Current Loss: 1.2861
# Epoch 2 | Batch 50 | Avg Loss: 1.3199 | Current Loss: 1.2705
# Epoch 2 | Batch 60 | Avg Loss: 1.3294 | Current Loss: 1.4307
# Epoch 2 | Batch 70 | Avg Loss: 1.3249 | Current Loss: 1.1572
# Epoch 2 | Batch 80 | Avg Loss: 1.3163 | Current Loss: 1.2500
# Epoch 2 | Batch 90 | Avg Loss: 1.3175 | Current Loss: 1.1982
# Epoch 2 | Batch 100 | Avg Loss: 1.3181 | Current Loss: 1.1924
# Epoch 2 | Batch 110 | Avg Loss: 1.3175 | Current Loss: 1.4775
# Epoch 2 | Batch 120 | Avg Loss: 1.3192 | Current Loss: 1.2344
# Epoch 2 | Batch 130 | Avg Loss: 1.3202 | Current Loss: 1.2539
# Epoch 2 | Batch 140 | Avg Loss: 1.3188 | Current Loss: 1.2148
# Epoch 2 | Batch 150 | Avg Loss: 1.3149 | Current Loss: 1.0186
# Epoch 2 | Batch 160 | Avg Loss: 1.3127 | Current Loss: 1.1641
# Epoch 2 | Batch 170 | Avg Loss: 1.3175 | Current Loss: 1.4189
# Epoch 2 | Batch 180 | Avg Loss: 1.3061 | Current Loss: 1.0010
# Epoch 2 | Batch 190 | Avg Loss: 1.3023 | Current Loss: 1.2773
# Epoch 2 | Batch 200 | Avg Loss: 1.3058 | Current Loss: 1.4033
# Epoch 2 | Batch 210 | Avg Loss: 1.2997 | Current Loss: 1.3008
# Epoch 2 | Batch 220 | Avg Loss: 1.3017 | Current Loss: 1.2832
# Epoch 2 | Batch 230 | Avg Loss: 1.3013 | Current Loss: 1.1768
# Epoch 2 | Batch 240 | Avg Loss: 1.2987 | Current Loss: 1.1836
# Epoch 2 | Batch 250 | Avg Loss: 1.2988 | Current Loss: 1.1904
# Epoch 2 | Batch 260 | Avg Loss: 1.2970 | Current Loss: 1.2373
# Epoch 2 | Batch 270 | Avg Loss: 1.2978 | Current Loss: 1.3545
# Epoch 2 | Batch 280 | Avg Loss: 1.2997 | Current Loss: 1.2959
# Epoch 2 | Batch 290 | Avg Loss: 1.3021 | Current Loss: 1.5010
# Epoch 2 | Batch 300 | Avg Loss: 1.3004 | Current Loss: 1.3066
# Epoch 2 | Batch 310 | Avg Loss: 1.2962 | Current Loss: 1.4043
# Epoch 2 | Batch 320 | Avg Loss: 1.2980 | Current Loss: 1.2617
# Epoch 2 | Batch 330 | Avg Loss: 1.2984 | Current Loss: 1.1650
# Epoch 2 | Batch 340 | Avg Loss: 1.2986 | Current Loss: 1.0879
# Epoch 2 | Batch 350 | Avg Loss: 1.2991 | Current Loss: 1.2285
# Epoch 2 | Batch 360 | Avg Loss: 1.2988 | Current Loss: 1.0303
# Epoch 2 | Batch 370 | Avg Loss: 1.2983 | Current Loss: 1.1533
# Epoch 2 | Batch 380 | Avg Loss: 1.2976 | Current Loss: 1.4238
# Epoch 2 | Batch 390 | Avg Loss: 1.2967 | Current Loss: 1.2285
# Epoch 2 | Batch 400 | Avg Loss: 1.2943 | Current Loss: 1.3428
# Epoch 2 | Batch 410 | Avg Loss: 1.2931 | Current Loss: 1.3486
# Epoch 2 | Batch 420 | Avg Loss: 1.2926 | Current Loss: 1.3184
# Epoch 2 | Batch 430 | Avg Loss: 1.2919 | Current Loss: 1.3447
# Epoch 2 | Batch 440 | Avg Loss: 1.2903 | Current Loss: 1.2939
# Epoch 2 | Batch 450 | Avg Loss: 1.2902 | Current Loss: 1.3320
# Epoch 2 | Batch 460 | Avg Loss: 1.2898 | Current Loss: 1.2959
# Epoch 2 | Batch 470 | Avg Loss: 1.2901 | Current Loss: 1.1357
# Epoch 2 | Batch 480 | Avg Loss: 1.2908 | Current Loss: 1.2285
# Epoch 2 | Batch 490 | Avg Loss: 1.2913 | Current Loss: 1.1152
#
# Epoch 2 completed
# Average epoch loss: 1.2908
# --------------------------------------------------

# %%
def generate_caption(image_path):
    """Generate a caption for a single image"""
    image = Image.open(image_path).convert('RGB')
    inputs = processor(images=image, return_tensors="pt").to("cuda", torch.float16)
    generated_ids = model.generate(**inputs, max_new_tokens=50)
    return processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()

def plot_images_with_captions(image_paths, captions):
    """Plot images with their generated captions"""
    plt.figure(figsize=(20, 12))
    for i, (img_path, caption) in enumerate(zip(image_paths, captions)):
        img = Image.open(img_path)
        plt.subplot(2, 3, i+1)  # 2 rows, 3 columns (for 5 images)
        plt.imshow(img)
        plt.title(caption, wrap=True, fontsize=10)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
image_dir = "/kaggle/input/flickr8k/Images"
image_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir)[5:10]]

# Generate captions
captions = [generate_caption(img_path) for img_path in image_files]

# Display results
print("Generated Captions:")
for img_path, caption in zip(image_files, captions):
    print(f"{os.path.basename(img_path)}: {caption}")

plot_images_with_captions(image_files, captions)
# Out:
# The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
# Both `max_new_tokens` (=50) and `max_length`(=51) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
# Both `max_new_tokens` (=50) and `max_length`(=51) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
# Both `max_new_tokens` (=50) and `max_length`(=51) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
# Both `max_new_tokens` (=50) and `max_length`(=51) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
# Both `max_new_tokens` (=50) and `max_length`(=51) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated Captions:
# 2752809449_632cd991b3.jpg: A man and a woman are sitting on a bus .
# 3097776588_312932e438.jpg: Two men smile at the camera .
# 1206506157_c7956accd5.jpg: Two dogs are playing in the grass .
# 1319634306_816f21677f.jpg: A brown dog is sitting on a hillside .
# 2465218087_fca77998c6.jpg: A man in a yellow kayak stands on the shore of a river .

# %%
save_path = "/kaggle/working/blip2_finetuned"
model.save_pretrained(save_path)
processor.save_pretrained(save_path)
# Out:
# ['/kaggle/working/blip2_finetuned/processor_config.json']

# %%
import shutil
import os

# Path to your saved model
save_path = "/kaggle/working/blip2_finetuned"

# Create zip archive
shutil.make_archive(
    base_name="blip2_finetuned_zip",  # Name without extension
    format="zip",                     # Compression format
    root_dir=os.path.dirname(save_path),  # Parent directory
    base_dir=os.path.basename(save_path)  # Folder to zip
)

print(f"Model zipped successfully: {os.path.abspath('blip2_finetuned_zip.zip')}")
# Out:
# Model zipped successfully: /kaggle/working/blip2_finetuned_zip.zip

# %%
# !pip install -q tqdm
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
from tqdm import tqdm

# Initialize metrics
bleu_evaluator = evaluate.load("bleu")
cider_evaluator = Cider()
caption_tokenizer = PTBTokenizer()

# Load dataset and prepare evaluation subset
caption_dataset = pd.read_csv("/kaggle/input/flickr8k/captions.txt",
                            sep=',',
                            names=["image_file", "caption_text"])
evaluation_samples = caption_dataset.iloc[8001:8092].reset_index(drop=True)

# Data storage structures
model_predictions = []
reference_captions = defaultdict(list)
ground_truth_dict = {}
result_dict = {}

# Process images and generate captions
processing_bar = tqdm(evaluation_samples.iterrows(), total=len(evaluation_samples))
for idx, sample in processing_bar:
    # Load and process image
    image_path = os.path.join("/kaggle/input/flickr8k/Images", sample['image_file'])
    input_image = Image.open(image_path).convert('RGB')

    # Generate prediction
    model_input = processor(images=input_image, return_tensors="pt").to(device, torch.float16)
    generated_output = model.generate(pixel_values=model_input.pixel_values,
                                    max_length=25)
    predicted_caption = processor.batch_decode(generated_output,
                                             skip_special_tokens=True)[0].strip()
    model_predictions.append(predicted_caption)

    # Store references
    if sample['image_file'] not in reference_captions:
        reference_captions[sample['image_file']] = caption_dataset[
            caption_dataset['image_file'] == sample['image_file']
        ]['caption_text'].tolist()

    # Prepare CIDEr format
    ground_truth_dict[str(idx)] = [{"caption": cap} for cap in reference_captions[sample['image_file']]]
    result_dict[str(idx)] = [{"caption": predicted_caption}]

processing_bar.close()

# Calculate BLEU score
bleu_score = bleu_evaluator.compute(
    predictions=model_predictions,
    references=[reference_captions[img] for img in evaluation_samples["image_file"]]
)

# Calculate CIDEr score
tokenized_ground_truth = caption_tokenizer.tokenize(ground_truth_dict)
tokenized_results = caption_tokenizer.tokenize(result_dict)
cider_score, _ = cider_evaluator.compute_score(tokenized_ground_truth, tokenized_results)

# Print results
print("\nEvaluation Metrics:")
print(f"BLEU Score: {bleu_score['bleu']:.4f}")
print(f"CIDEr Score: {cider_score:.4f}")
# Out:
#   0%|          | 0/91 [00:00<?, ?it/s]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#   1%|          | 1/91 [00:03<05:00,  3.34s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#   2%|▏         | 2/91 [00:06<04:59,  3.36s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#   3%|▎         | 3/91 [00:10<04:55,  3.36s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#   4%|▍         | 4/91 [00:13<04:50,  3.33s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#   5%|▌         | 5/91 [00:16<04:45,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#   7%|▋         | 6/91 [00:20<04:44,  3.34s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#   8%|▊         | 7/91 [00:23<04:43,  3.38s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#   9%|▉         | 8/91 [00:26<04:39,  3.37s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  10%|▉         | 9/91 [00:30<04:36,  3.37s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  11%|█         | 10/91 [00:33<04:32,  3.37s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  12%|█▏        | 11/91 [00:37<04:30,  3.39s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  13%|█▎        | 12/91 [00:40<04:26,  3.38s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  14%|█▍        | 13/91 [00:43<04:20,  3.34s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  15%|█▌        | 14/91 [00:46<04:17,  3.34s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  16%|█▋        | 15/91 [00:50<04:16,  3.38s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  18%|█▊        | 16/91 [00:53<04:14,  3.39s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  19%|█▊        | 17/91 [00:57<04:10,  3.39s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  20%|█▉        | 18/91 [01:00<04:05,  3.36s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  21%|██        | 19/91 [01:03<04:02,  3.37s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  22%|██▏       | 20/91 [01:07<03:58,  3.35s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  23%|██▎       | 21/91 [01:10<03:54,  3.34s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  24%|██▍       | 22/91 [01:13<03:49,  3.33s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  25%|██▌       | 23/91 [01:17<03:46,  3.33s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  26%|██▋       | 24/91 [01:20<03:42,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  27%|██▋       | 25/91 [01:23<03:38,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  29%|██▊       | 26/91 [01:27<03:34,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  30%|██▉       | 27/91 [01:30<03:30,  3.29s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  31%|███       | 28/91 [01:33<03:28,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  32%|███▏      | 29/91 [01:36<03:24,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  33%|███▎      | 30/91 [01:40<03:21,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  34%|███▍      | 31/91 [01:43<03:17,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  35%|███▌      | 32/91 [01:46<03:14,  3.29s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  36%|███▋      | 33/91 [01:50<03:12,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  37%|███▋      | 34/91 [01:53<03:08,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  38%|███▊      | 35/91 [01:56<03:05,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  40%|███▉      | 36/91 [02:00<03:02,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  41%|████      | 37/91 [02:03<02:58,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  42%|████▏     | 38/91 [02:06<02:56,  3.33s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  43%|████▎     | 39/91 [02:10<02:51,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  44%|████▍     | 40/91 [02:13<02:47,  3.28s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  45%|████▌     | 41/91 [02:16<02:44,  3.29s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  46%|████▌     | 42/91 [02:19<02:41,  3.29s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  47%|████▋     | 43/91 [02:23<02:37,  3.28s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  48%|████▊     | 44/91 [02:26<02:33,  3.27s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  49%|████▉     | 45/91 [02:29<02:30,  3.27s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  51%|█████     | 46/91 [02:33<02:28,  3.29s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  52%|█████▏    | 47/91 [02:36<02:25,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  53%|█████▎    | 48/91 [02:39<02:23,  3.35s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  54%|█████▍    | 49/91 [02:43<02:19,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  55%|█████▍    | 50/91 [02:46<02:15,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  56%|█████▌    | 51/91 [02:49<02:12,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  57%|█████▋    | 52/91 [02:52<02:09,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  58%|█████▊    | 53/91 [02:56<02:05,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  59%|█████▉    | 54/91 [02:59<02:02,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  60%|██████    | 55/91 [03:02<01:59,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  62%|██████▏   | 56/91 [03:06<01:56,  3.34s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  63%|██████▎   | 57/91 [03:09<01:53,  3.35s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  64%|██████▎   | 58/91 [03:12<01:50,  3.34s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  65%|██████▍   | 59/91 [03:16<01:46,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  66%|██████▌   | 60/91 [03:19<01:42,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  67%|██████▋   | 61/91 [03:22<01:39,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  68%|██████▊   | 62/91 [03:26<01:35,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  69%|██████▉   | 63/91 [03:29<01:32,  3.29s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  70%|███████   | 64/91 [03:32<01:28,  3.28s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  71%|███████▏  | 65/91 [03:35<01:25,  3.28s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  73%|███████▎  | 66/91 [03:39<01:22,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  74%|███████▎  | 67/91 [03:42<01:19,  3.33s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  75%|███████▍  | 68/91 [03:45<01:16,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  76%|███████▌  | 69/91 [03:49<01:13,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  77%|███████▋  | 70/91 [03:52<01:09,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  78%|███████▊  | 71/91 [03:55<01:06,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  79%|███████▉  | 72/91 [03:59<01:03,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  80%|████████  | 73/91 [04:02<00:59,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  81%|████████▏ | 74/91 [04:05<00:56,  3.29s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  82%|████████▏ | 75/91 [04:09<00:52,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  84%|████████▎ | 76/91 [04:12<00:49,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  85%|████████▍ | 77/91 [04:15<00:46,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  86%|████████▌ | 78/91 [04:19<00:43,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  87%|████████▋ | 79/91 [04:22<00:39,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  88%|████████▊ | 80/91 [04:25<00:36,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  89%|████████▉ | 81/91 [04:29<00:33,  3.33s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  90%|█████████ | 82/91 [04:32<00:29,  3.32s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  91%|█████████ | 83/91 [04:35<00:26,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  92%|█████████▏| 84/91 [04:38<00:23,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  93%|█████████▎| 85/91 [04:42<00:19,  3.29s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  95%|█████████▍| 86/91 [04:45<00:16,  3.29s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  96%|█████████▌| 87/91 [04:48<00:13,  3.31s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  97%|█████████▋| 88/91 [04:52<00:09,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  98%|█████████▊| 89/91 [04:55<00:06,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
#  99%|█████████▉| 90/91 [04:58<00:03,  3.30s/it]The `language_model` is not in the `hf_device_map` dictionary and you are running your script in a multi-GPU environment. this may lead to unexpected behavior when using `accelerate`. Please pass a `device_map` that contains `language_model` to remove this warning. Please refer to https://github.com/huggingface/blog/blob/main/accelerate-large-models.md for more details on creating a `device_map` for large models.
# 100%|██████████| 91/91 [05:02<00:00,  3.32s/it]
# PTBTokenizer tokenized 6093 tokens at 47978.50 tokens per second.
# PTBTokenizer tokenized 1114 tokens at 13854.29 tokens per second.
# Evaluation Metrics:
# BLEU Score: 0.3767
# CIDEr Score: 1.1191
